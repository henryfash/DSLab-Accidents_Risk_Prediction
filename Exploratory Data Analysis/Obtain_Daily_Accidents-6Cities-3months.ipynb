# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
import warnings; warnings.simplefilter('ignore')
from code_files_feature_extraction import *

# %matplotlib inline
import datetime

# %%
arp_df = pd.read_csv('US_Accidents_June20.csv')

# %%
arp_df_ts = arp_df[['ID','Start_Time','City']]
arp_df_ts.head(7)
# Out:
#     ID           Start_Time          City
# 0  A-1  2016-02-08 05:46:00        Dayton
# 1  A-2  2016-02-08 06:07:59  Reynoldsburg
# 2  A-3  2016-02-08 06:49:27  Williamsburg
# 3  A-4  2016-02-08 07:23:34        Dayton
# 4  A-5  2016-02-08 07:39:07        Dayton
# 5  A-6  2016-02-08 07:44:26   Westerville
# 6  A-7  2016-02-08 07:59:35        Dayton

# %%
arp_df_ts.shape
# Out:
# (3513617, 3)

# %%
cities = ['Houston', 'Atlanta', 'LosAngeles', 'Charlotte', 'Dallas', 'Austin']
cities_df = arp_df_ts.loc[arp_df_ts['City'].isin(cities)].reset_index(drop=True)

# %%
cities_df.shape
# Out:
# (349997, 3)

# %%
#cities_df.head(18)

# %%
cities_dff = cities_df[['ID','Start_Time']]

# %%
cities_dff['Date'] = pd.DatetimeIndex(cities_dff['Start_Time']).to_period('D')
cities_dff['Month'] = pd.to_datetime(cities_dff['Start_Time']).dt.month
#cities_dff['Date'] = pd.DatetimeIndex(cities_dff['Start_Time']).to_period('W')
cities_dff.head(2)
# Out:
#          ID           Start_Time        Date  Month
# 0  A-146263  2016-11-30 15:25:27  2016-11-30     11
# 1  A-146264  2016-11-30 14:42:27  2016-11-30     11

# %%
# cities_dff['Date'] = pd.to_datetime(cities_dff['Date'])
# df['Month'] = df['Date'].dt.month

# %%
cities_dff.drop(['Start_Time'],axis = 1, inplace=True)

# %%
cities_dff.isnull().sum()
# Out:
# ID       0
# Date     0
# Month    0
# dtype: int64

# %%
cities_dff.head(2)
# Out:
#          ID        Date  Month
# 0  A-146263  2016-11-30     11
# 1  A-146264  2016-11-30     11

# %%
cities_dff_N =cities_dff[(cities_dff["Month"]==6) | (cities_dff["Month"]==7) | (cities_dff["Month"]==8)].reset_index()
cities_dff_N
# Out:
#         index         ID        Date  Month
# 0        3921   A-155415  2016-08-01      8
# 1        3922   A-155417  2016-08-01      8
# 2        3923   A-155418  2016-08-01      8
# 3        3924   A-155419  2016-08-01      8
# 4        3925   A-155420  2016-08-01      8
# ...       ...        ...         ...    ...
# 84532  349992  A-3513511  2019-08-23      8
# 84533  349993  A-3513513  2019-08-23      8
# 84534  349994  A-3513514  2019-08-23      8
# 84535  349995  A-3513515  2019-08-23      8
# 84536  349996  A-3513518  2019-08-23      8
#
# [84537 rows x 4 columns]

# %%
cities_dff_N.shape
# Out:
# (84537, 4)

# %%
# arp_df_Day = arp_df_ts.groupby('Date')['ID'].count().reset_index()
# arp_df_Day.head(2)

# %%
cities_dff_N = cities_dff_N.groupby('Date')['ID'].count().reset_index()
cities_dff_N.tail(60)
# Out:
#            Date   ID
